# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# 3-intro.png![image.png](attachment:8c994bb6-c599-475d-b6e8-63e0b690ba63.png)

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# 3-intro.png![image.png](attachment:385bdde1-8aaf-40db-bd1b-b58bdf0e18e2.png)

# %% [markdown]
# # some of the popular languages that Data Scientists use are:
# 1. python
# 2. SQL
# 3. R

# %% [markdown]
# 4-dslanguages.png![image.png](attachment:65de7855-c020-4e02-933d-1cbaaabb2f8f.png)

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
# 1. numpy
# 2. pandas
# 3. matplotlib

# %% [markdown]
# 5-dslibraries.png![image.png](attachment:a6e390af-5b5b-4dc3-9d54-45c3cf7ee02a.png)

# %% [markdown]
# | Data Science Tools |
# | -------------|
# | Jupyter Notebooks |
# | RStudio |
# | Visual Studio Code (VSCode) |

# %% [markdown]
# 6-dstools.png![image.png](attachment:5b0e43a9-dd9a-4f0f-a13b-394a7e523042.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# 7-introarithmetic.png![image.png](attachment:8ea67946-77c5-4df0-91d1-5bf3b1f3fbba.png)

# %%
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# 8-multiplyandaddintegers.png![image.png](attachment:709fc5ba-1aa4-4f64-b196-7e76a9ae0c6c.png)

# %%
#This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# 9-hourstominutes.png![image.png](attachment:0a240883-408a-4bd6-80d6-eb43e23131cd.png)

# %% [markdown]
# **Objectives:**
# + Jupyter
# + Rstudio
# + GIT
# + Git hub

# %% [markdown]
# 10-objectives.png![image.png](attachment:d8eeef47-6d20-43a0-85fc-055bc934f4fd.png)

# %% [markdown]
# ## Author
# farah mohamed azmy

# %% [markdown]
# 11-authordetails.png![image.png](attachment:5e5d11cb-80df-4a6f-9f06-138dc324125b.png)
